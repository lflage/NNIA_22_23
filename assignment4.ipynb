# %% [markdown]
# # NNIA Assignment 4
#
# **DEADLINE: 7. 12. 2021 08:00 CET**
# Submission more than 10 minutes past the deadline will **not** be graded!
#
# - Name & ID 1 (Teams username e.g. s8xxxxx):
# - Name & ID 2 (Teams username e.g. s8xxxxx):
# - Hours of work per person:
#
# # Submission Instructions
#
# **IMPORTANT** Please make sure you read the following instructions carefully. If you are unclear about any part of the assignment, ask questions **before** the assignment deadline. All course-related questions can be addressed on the course **[Piazza Platform](https://piazza.com/class/kvc3vzhsvh55rt)**.
#
# * Assignments are to be submitted in a **team of 2**.
# * Please include your **names**, **ID's**, **Teams usernames**, and **approximate total time spent per person** at the beginning of the Notebook in the space provided
# * Make sure you appropriately comment your code wherever required.
# * Your final submission should contain this completed Jupyter Notebook, including the bonus question (if you attempt it), and any necessary Python files.
# * Do **not** submit any data or cache files (e.g. `__pycache__`).
# * Upload the **zipped** folder (*.zip* is the only accepted extension) in **Teams**.
# * Only **one member** of the group should make the submisssion.
# * **Important** please name the submitted zip folder as: `Name1_id1_Name2_id2.zip`. The Jupyter Notebook should also be named: `Name1_id1_Name2_id2.ipynb`. This is **very important** for our internal organization epeatedly students fail to do this.

# %% [markdown]
# ## 1 Calculus Revision (6 points)
#
# ### 1.1 Critical Points (2 points)
#
# Consider the following functions: $f(x)=5x^2 +4x^3 −10$ and $g(x)=6(x−3)^3 +2$.
#
# 1. Compute the first derivatives for both functions. (0.5 pts)
# 2. Compute the second derivatives for both functions. (0.5 pts)
# 3. Find all critical points for both functions (using first and second derivatives) and give their types (refer to lecture slides). Make sure to comment on how one determines the types of critical points. (1 pt)
#
# ### 1.2 Local and Global (3 points)
#
# Some functions have more than one or two critical points such as function $h(x)=4x^2sin(x)+\frac{e^x}{e^x+1} + x^3$.
# 1. Compute the first derivative for $h$. (Hint: Use the Product and Quotient rules). (1 pt)
# 2. Plot $h$ for the interval $x \in (-4,5)$. Use an online resource like Wolfram Alpha or Desmos. (0.5 pt)
# 3. Find the critical points from left to right and name them as $p_1, p_2,...p_n$ (no need for exact coordinates). For each point determine its type and if it is local or global. (0.5)
# 4. Why can local minima cause optimization algorithms to fail? (0.5)
#
# ### 1.3 Activation Functions (1.5 points)
#
# Three of the most commonly-used activation functions are the sigmoid function, hyperbolic tangent, and ReLU. The equations for these functions are provided below:
#
# * $\sigma(x) = \frac{1}{1+e^{-x}}$
#
# * $\tanh(x) = \frac{e^{2x} - 1}{e^{2x} + 1}$
#
# * $\text{ReLU}(x) =  \bigg\{ \begin{array}{ll} 0, & x < 0 \\ x, & x > 0 \\ \end{array}$
#
# Again, using code or an online resource like Wolfram Alpha or Desmos, graph each function along with its derivative. Make sure to include the plots in your solution.
# 1. Discuss the differences you observe. (1 sentence)
# 2. What are the advantages and disadvantages of each? In particular, think about how the range of the function and the amplitude of the derivative would affect a network. (2 sentences)

# %% [markdown]
# ### 1.1 <font color="red">Done</font>
#
# 1. #Compute the first derivatives for both functions.
#
# $f(x)=5x^2 +4x^3 −10$
#
# $f'(x)=10x +12x^2$
#
# $g(x)=6(x−3)^3 +2$
#
# $g'(x)=18(x-3)^2$
#
#
# 2. #Compute the second derivatives for both functions.
#
# $f(x)=5x^2 +4x^3 −10$
#
# $f''(x)=10 +24x$
#
# $g(x)=6(x−3)^3 +2$
#
# $g''(x)=36(x-3)$
#
# 3. #Find all critical points for both functions (using first and second derivatives) and give their types (refer to lecture slides). Make sure to comment on how one determines the types of critical points
#
# $f(x)$ critical points are 0 and -5/6
#
# $g(x)$ critical point is 1
#
# To find out the types of the critical points, we can use the "Second Derivative Test for Local Extrema".
#
# $f''(0)= 10 + 24 (0)= 10$
#
# The second deravative at the first critical point is positive (=0) so the corresponding critical point (0) is the local minimum of the function.
#
# $f''(-5/6)= 10 + 24 (-5/6)= -10$
#
# The second deravative at the first critical point is negative (<0) so the corresponding critical point (-5/6) is the local maximum of the function.
#
# $g''(1)= 36(x-1)= 1$
#
# The second deravative at the first critical point is negative (<0) so the corresponding critical point (1) is the local maximum of the function.
#
# Is there another critical point of the last function?

# %% [markdown]
# ### 1.2 <font color="red">Done</font>
#
# $h(x)=4x^2sin(x)+\frac{e^x}{e^x+1} + x^3$.
#
# 1. Compute the first derivative for $h$. (Hint: Use the Product and Quotient rules).
#
# $h'(x)=8x cos(x) +sin(x) 8x +e^x -e^x^2 +3x^2$
#
# 2. Plot  ℎ  for the interval  𝑥∈(−4,5)
# ![plot_nn_1.2.png](attachment:plot_nn_1.2.png)
#
# 3. Find the critical points from left to right and name them as  𝑝1,𝑝2,...𝑝𝑛  (no need for exact coordinates). For each point determine its type and if it is local or global.
#
# $p1$= (-2,8;-31) --> global minimum
# $p2$= (0;2) --> saddle
# $p3$= (4,5;12) --> local maximum
# $p4$= (2,8;34) --> global maximum
#
# 4. Why can local minima cause optimization algorithms to fail?
#
# They are not the lowest loss we can achieve during optimization, which is the point corresponding to the global minima. Now, if you initialze your weights at point A, then you're gonna converge to the local minima, and gradient descent will not go out of there, once you converge to the local minima.
#
# Local minimum are called so since the value of the loss function is minimum at that point in a local region. Whereas, a global minima is called so since the value of the loss function is minimum there, globally across the entire domain the loss function.

# %% [markdown]
# ### 1.3 <font color="red">Done</font>
#
# 1. Graph each function along with its derivative. Make sure to include the plots in your solution.
#
# **Sigmoid Function:**
# ![sigmoid.png](attachment:sigmoid.png)
#
#
# **Tanh Function:**
#
# ![tahn.png](attachment:tahn.png)
#
# **Relu Function:**
# ?
#
# #Discuss the differences you observe.
#
# Sigmoid and Tahn are sigmoidal (S-shaped) and are comprised in an interval (sigmoid between 0 and 1, tahn between -1 and 1), wherease ReLu is half rectified and comprised between 0 and infinite.
#
#
# 2. What are the advantages and disadvantages of each? In particular, think about how the range of the function and the amplitude of the derivative would affect a network.
#
# Sigmoid:-
#
# Normally used as the output of a binary probabilistic function.
#
# Advantages:
#
# -> Gives you a smooth gradient while converging.
#
# -> One of the best Normalised functions.
#
# -> Gives a clear prediction(classification) with 1 & 0.
#
# Disadvantages:
#
# -> Prone to Vanishing Gradient problem.
#
# -> Not a zero-centric function(Always gives a positive values).
#
# -> Computationally expensive function(exponential in nature).
#
#
#
# Tanh:-
#
# Normally used as the input of a binary probabilistic function.
#
# Advantages:
#
# -> Zero-centric function unlike Sigmoid.
#
# -> It is a smooth gradient converging function.
#
# Disadvantages:
#
# -> Prone to Vanishing Gradient function.
#
# -> Computationally expensive function(exponential in nature).
#
# RELU:-(Rectified Linear Unit)
#
# Advantages:
#
# -> Can deal with Vanishing Gradient problem.
#
# -> Computationally inexpensive function(linear in nature).
#
# Disadvantages:
#
# -> Not a zero-centric function.
#
# -> Gives zero value as inactive in the negative axis.

# %% [markdown]
# ## 2.3 Neural Networks Hello World (4 points)
#
# Construct a neural network for the California Housing Prices dataset.
# It is composed of two linear layers with hidden dimensionality of $32$ and ReLU after the first layer: $L_{8\rightarrow 32} \circ \text{ReLU} \circ L_{32 \rightarrow 1}$ where $L_{x\rightarrow y}$ is a linear layer with $y$ hidden nodes (`nn.Linear(x, y)`).
#
# Split your data into dev and training sets (1000 training, 100 dev, discard rest) and optimize these networks with Adam with learning rate $10^{-3}$.
# Report MSE on both training and dev sets. You can use PyTorch built-in functions to solve this exercise.
#
# Notes:
# - Please read [this introduction to the optimization loop in PyTorch](https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html). It should give you a good overview to what PyTorch needs from you to train a neural network.
# - Run your training multiple times with different seeds because the results have quite high variance.
# - There are many optimizers available and Adam is an optimizer that's more complex than SGD (stochastic gradient descent). It has not yet been covered in the lecture but its usage in code is equivalent to that of SGD and performs much better.

# %%
# TODO
# from your solution module import ...
# your outputs should include Training MSE and Dev MSE.
# useful imports
from sklearn.datasets import fetch_california_housing
import torch
import torch.nn as nn

from torch.nn import Module
from torch.nn import functional as F
import torch.optim as optim
import torch.utils.data as data_utils
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from sklearn.model_selection import train_test_split

from sklearn.datasets import fetch_california_housing, load_diabetes

# preprocessing of the dataset


housing = fetch_california_housing()
input_data = housing.data
output_data = housing.target
feature_names = housing.feature_names

X_train, X_test, y_train, y_test = train_test_split(input_data,output_data,test_size=100,random_state=42)

X_train=torch.from_numpy(X_train[:1000])
X_test=torch.from_numpy(X_test)
y_train=torch.reshape(torch.from_numpy(y_train[:1000]),(1000,1))
#y_train_reshaped=torch.reshape(y_train(len(y_train),1))
#print(y_train)
#y_test=torch.from_numpy(y_test)
y_test=torch.reshape(torch.from_numpy(y_test[:100]),(100,1))
#y_test=torch.reshape(y_test(len(y_test),1))
#print(y_test)

train_data= data_utils.TensorDataset(X_train,y_train)
train_dataloader= data_utils.DataLoader(train_data)

test_data= data_utils.TensorDataset(X_test,y_test)
test_dataloader= data_utils.DataLoader(test_data)

# %%
# The function "torch.cuda.is_available()" checks and returns True if a GPU is available, else False
is_cuda = torch.cuda.is_available()

# If GPU is available--> set device to GPU
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
    
# setting the hyperparameters of the model    
hyper_params = {
    "input_dim": 1,
    "hidden_size": 32,
    "output_dim": 1,
    "num_layers": 2,
    "num_classes": 8,
    "batch_size": 10,
    "num_epochs": 3,
    "learning_rate": 0.001
} 

test_size=1000
dev_size=100

class nn_model(nn.Module):
    
    def __init__(self, input_dim: int, hidden_size: int, output_dim: int):
        
        print(input_dim, hidden_size, output_dim)

        # initialization step
        super(nn_model, self).__init__()
        self.hidden_size = hidden_size

        # Layer num 1

        self.layer1= nn.Linear(input_dim, hidden_size) #dropout can be added as one of the parameters of nn.Model

        # Linear layer (layer num 2, output layer)

        self.layer2= nn.Linear(hidden_size, output_dim)

        # initialize hidden state
        self.hidden=self.init_hidden()
    
    def init_hidden(self):
        '''
        Function that initializes a hidden state with zeros   
        '''
        # the axes dimensions are (n_layers, batch_size, self.hidden_size)
        return (torch.zeros(2, self.hidden_size).to(device),
                torch.zeros(2, self.hidden_size).to(device))
        
        
    def forward(self, data): # where data = input tensor
        '''
        Function that defines how the model should behave
        '''
        # reshaped output and hidden state obtained by passing through the first layer
        NN_out, _ = self.layer1(len(data), -1)
        # apply (ReLu) activation function 
        NN_out= torch.relu(NN_out)
        # get most likely tag for each word of the sentence that was received as input
        output = self.layer2(len(sentence), -1) # CHANGE
     
        return output
    

#### choice of model parameters  ####
for train in train_data:
    input_dim=int(train[0].size()[0])
hidden_size= hyper_params["hidden_size"]
output_dim= hyper_params["output_dim"]
number_classes= hyper_params["num_classes"] 

#### instantiate the model ####
nn_model = NN_model(input_dim=input_dim, hidden_size=hidden_size, output_dim=output_dim)
nn_model.to(device)

#### definition of training parameters ####
num_epochs=hyper_params['num_epochs']
optimizer = optim.Adam(nn_model.parameters(), lr=hyper_params['learning_rate']) 
loss = nn.MSELoss()

# %%
#### Trainig the model ####
print(f'--------- #### Training starts #### ------------')

def train(model: Module, 
          loss,
          train_data: DataLoader,
          optimizer,
          num_epochs: int):
    '''
    Function that takes these parameters as input:
    model: MLP
    loss: MSE
    training_data: train_data
    optimizer: Adam with learning rate 0.001
    epochs number
    
    And returns:
    trained model on training corpus
    '''
    # Bring model into training mode 
    model.train()
    
    all_acc=[]
    all_loss=[]
                
    # run training for each epoch
    for epoch in tqdm(range(hyper_params['num_epochs']), desc='Model Training\n'):
        epoch+=1
        train_correct=0
        num_sample=1
        epoch_losses=[]
        epoch_accs=[]
        step=0 
        
        print('\n')
        print(f'--------- #### Started Epoch {epoch} #### ------------')

        # iteration over data
        for i, element in enumerate(train_data):
            print(element)
            # need to clear gradients that have been accumulated for each instance before proceeding
            model.zero_grad()
            
            # initialize hidden state
            model.hidden=nn_model.init_hidden()
            
            # get inputs and corresponding labels
            data=element[0][0].to(device)
            print(data[0])
            target=element[1][0].to(device)
            
            # run the forward pass 
            scores = model.forward(data)
            
            # compute the loss
            loss = loss_fn(tag_scores, tags) # loss per element in training_data
            epoch_losses.append(loss.item()) # saves all the losses experienced during this particular training epoch
            
            # compute evaluation metrics to evaluate the model performance based on predictions of the model
            _, predicted_class=torch.max(scores, 1)
            
            # compute the accuracy per each epoch
            accuracy=(predicted_class==target).sum()/len(target) #accuracy per element: how many tags where guessed correctly per each element
            epoch_accs.append(accuracy.item())  # saves all accuracies per epoch

            # back propagation of the loss
            optimizer.zero_grad()
            loss.backward()
            # optimize parameters
            optimizer.step()
        
            num_sample+=1
        
            # print some outputs in the console so that we can visualize the state of the training step
            if (i + 1) % 3000 == 0:
                print('Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Accuracy: %.4f'
                      % (epoch, hyper_params['num_epochs'], i + 1, len(train_data), loss.item(), accuracy))
        
        # compute mean loss and mean accuracy of all elements per single epoch
        epoch_loss=sum(epoch_losses)/(num_sample-1) 
        epoch_accuracy=sum(epoch_accs)/(num_sample-1)
        
        # print some info about metrics per each epoch
        print('\n') 
        print("Accuracy for epoch", epoch,": {}".format(epoch_accuracy*100))
        print ("Training loss per epoch", epoch,":", epoch_loss)
        
        # save all epochs' losses and accuracies 
        all_acc.append(epoch_accuracy)
        all_loss.append(epoch_loss)

    # compute mean accuracy and mean loss in relation of the whole training step    
    mean_accuracy=sum(all_acc)/num_epochs
    mean_loss=sum(all_loss)/num_epochs
    
    print("Mean accuracy of training:", mean_accuracy*100)
    print("Mean loss of training:", mean_loss)
    
# actually train the model with the previous function
train(model=nn_model, train_data=train_dataloader, num_epochs=num_epochs,
            optimizer=optimizer, loss=loss)



#### Saving the model parameters in a .pt file ####
torch.save(nn_model.state_dict(), "./model_parameters_tagger.pt")

# load trained model parameters again
# instantiate the saved model before using it
trained_model = nn_model(input_dim=input_dim, hidden_size=hidden_size, output_dim=output_dim)

# load the trained parameters
trained_model.load_state_dict(torch.load("./model_parameters_tagger.pt"))
# Out:
# Model Training
# Model Training                                                                    | 0/3 [00:00<?, ?it/s]
# :   0%|                                                                           | 0/3 [00:00<?, ?it/s]
# --------- #### Training starts #### ------------
#
#
# --------- #### Started Epoch 1 #### ------------
# [tensor([[   3.0598,   13.0000,    4.3101,    1.0698,  776.0000,    2.1676,
#            34.0400, -117.6700]], dtype=torch.float64), tensor([[0.9970]], dtype=torch.float64)]
# tensor(3.0598, dtype=torch.float64)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-371e60ba6923> in <module>
#      98
#      99 # actually train the model with the previous function
# --> 100 train(model=nn_model, train_data=train_dataloader, num_epochs=num_epochs,
#     101             optimizer=optimizer, loss=loss)
#     102
#
# ...

# %%
#### evaluation of the model on test set ####
# bring model into evaluation mode
trained_tagger.eval()

test_num_corrects=0
test_example_count=0
test_epoch_accs=[]
all_test_acc=[]
test_num_sample=0
big_accuracy=0.0

#### Test step 
print('------------------------------------------------------------------------')
print('\n')
print(f'--------- #### Evaluating Model on test set #### ----------')     
with torch.no_grad():
    for test in test_data:

        data_test=test[0][0].to(device)
        target_test=test[0][1].to(device)
        
        scores=trained_tagger(sent_test)
        
        # compute evaluation metrics to evaluate the model performance based on predictions of the model
        _, predicted_tags=torch.max(tag_scores, 1)
        
        # statistics
        test_num_corrects += torch.sum(predicted_tags == tags_test).item()
        test_example_count += predicted_tags.size(0)

    
        test_num_sample+=1
        
    actual=tags_test
    pred=predicted_tags
    f1_score_test= f1_score(actual, pred, average='weighted')


print(f'Got a test accuracy of {float(test_num_corrects/float(test_example_count))*100:.4f} and a f1 score of {float(f1_score_test):.4f} on the test set')

# %% [markdown]
# # Bonus Learning Rate Effect on Performance (1 point)
#
# Run your neural network with different learning rates (scale logarithmically from $10^{-10}$ to $10^{0}$) and observe the effects on performance. Importantly keep the number of optimization steps (epochs) constant. Because the process is very random run the model multiple times (e.g. 3 times) and plot the results. Try to form hypothesis about the results which you got.
#
# Don't worry, the model training can be done on a CPU and is not computationally intensive.
