# %% [markdown]
# # NNIA Assignment 4
#
# **DEADLINE: 7. 12. 2021 08:00 CET**
# Submission more than 10 minutes past the deadline will **not** be graded!
#
# - Benedict Schneider 7009917 (BESC0005): 8 hrs
# - Iris Ferazzo 7028674 (IRFE001): 8 hrs
# - Lucas Fonseca Lage 7024877 (LUFO00001): 8 hrs
#
# # Submission Instructions
#
# **IMPORTANT** Please make sure you read the following instructions carefully. If you are unclear about any part of the assignment, ask questions **before** the assignment deadline. All course-related questions can be addressed on the course **[Piazza Platform](https://piazza.com/class/kvc3vzhsvh55rt)**.
#
# * Assignments are to be submitted in a **team of 2**.
# * Please include your **names**, **ID's**, **Teams usernames**, and **approximate total time spent per person** at the beginning of the Notebook in the space provided
# * Make sure you appropriately comment your code wherever required.
# * Your final submission should contain this completed Jupyter Notebook, including the bonus question (if you attempt it), and any necessary Python files.
# * Do **not** submit any data or cache files (e.g. `__pycache__`).
# * Upload the **zipped** folder (*.zip* is the only accepted extension) in **Teams**.
# * Only **one member** of the group should make the submisssion.
# * **Important** please name the submitted zip folder as: `Name1_id1_Name2_id2.zip`. The Jupyter Notebook should also be named: `Name1_id1_Name2_id2.ipynb`. This is **very important** for our internal organization epeatedly students fail to do this.

# %% [markdown]
# ## 1 Calculus Revision (6 points)
#
# ### 1.1 Critical Points (2 points)
#
# Consider the following functions: $f(x)=5x^2 +4x^3 −10$ and $g(x)=6(x−3)^3 +2$.
#
# 1. Compute the first derivatives for both functions. (0.5 pts)
# 2. Compute the second derivatives for both functions. (0.5 pts)
# 3. Find all critical points for both functions (using first and second derivatives) and give their types (refer to lecture slides). Make sure to comment on how one determines the types of critical points. (1 pt)
#
# ### 1.2 Local and Global (3 points)
#
# Some functions have more than one or two critical points such as function $h(x)=4x^2sin(x)+\frac{e^x}{e^x+1} + x^3$.
# 1. Compute the first derivative for $h$. (Hint: Use the Product and Quotient rules). (1 pt)
# 2. Plot $h$ for the interval $x \in (-4,5)$. Use an online resource like Wolfram Alpha or Desmos. (0.5 pt)
# 3. Find the critical points from left to right and name them as $p_1, p_2,...p_n$ (no need for exact coordinates). For each point determine its type and if it is local or global. (0.5)
# 4. Why can local minima cause optimization algorithms to fail? (0.5)
#
# ### 1.3 Activation Functions (1.5 points)
#
# Three of the most commonly-used activation functions are the sigmoid function, hyperbolic tangent, and ReLU. The equations for these functions are provided below:
#
# * $\sigma(x) = \frac{1}{1+e^{-x}}$
#
# * $\tanh(x) = \frac{e^{2x} - 1}{e^{2x} + 1}$
#
# * $\text{ReLU}(x) =  \bigg\{ \begin{array}{ll} 0, & x < 0 \\ x, & x > 0 \\ \end{array}$
#
# Again, using code or an online resource like Wolfram Alpha or Desmos, graph each function along with its derivative. Make sure to include the plots in your solution.
# 1. Discuss the differences you observe. (1 sentence)
# 2. What are the advantages and disadvantages of each? In particular, think about how the range of the function and the amplitude of the derivative would affect a network. (2 sentences)

# %% [markdown]
# ### 1.1 <font color="green">Done</font>
#
# #### 1.
#
# $f(x)=5x^2 +4x^3 −10 $
#
# Applying the power rule and the constant rule:
#
# $f'(x)= 2*5x^1 + 3*4x^2 = 10x + 12x^2$
#
# ----------
#
# $g(x)=6(x−3)^3 +2$
#
# Factoring out the constant, applying the constant rule:
#
# $g'(x)=6*g'((x−3)^3) +g'(2) = 6*g'((x−3)^3) + 0$
#
# Applying the chain rule:
#
# $6*g'((x−3)^3) = 6* 3(x-3)^2*g'(x-3)= 18*(x-3)^2*g'(x-3)$
#
# Applying the sum rule:
#
# $18*(x-3)^2*g'(x-3) = 18(x-3)^2*(g'(x) + g'(-3)) = 18(x-3)^2*(1+0) = 18(x-3)^2$
#
#
#
# #### 2.
#
# $f'(x) = 10x + 12x^2$
#
# Sum rule, power rule:
#
# $f''(x) = 10 + 24x$
#
# ----
#
# $g'(x) = 18(x-3)^2$
#
# Chain rule:
#
# $g''(x)= 36(x-3) * (1+0) = 36(x-3)$
#
# #### 3.
#
# To find the critical points, we have to set the first derivative of the function to 0.
#
# $f'(x)= 10x + 12x^2$
#
# $ 10x + 12x^2 = 0 $   | Factoring
#
# $ 2x*(5 + 6x) = 0 $
#
# This will be 0 if either
#
# $ 5+6x = 0 $
#
# $ x_1 = -\frac{5}{6} $
#
# Or
#
# $ 2x = 0 $
#
# $ x_2 = 0 $
#
# To find out if those are minima,maxima or saddle points, we can use the "Second Derivative Test for Local Extrema"
#
# $ f''(x_1) = 10 + 24*-\frac{5}{6} = -10 $
#
# Since the second derivative at $x_1$ is negative, $x_1$ is a maximum.
#
# $ f''(x_2) = 10 + 24*0 = 10$
#
# Since the the second derivative at $x_2$  is positive, $x_2$ is a minimum.

# %% [markdown]
# ### 1.2 <font color="green">Done</font>
#
# 1.   $h(x)=4x^2sin(x)+\frac{e^x}{e^x+1} + x^3$
#
# Computing the first derivative:
#
# Sum rule:
#
# $h'(x) = h'(4x^2sin(x))+h'(\frac{e^x}{e^x+1})+h'(x^3)$
#
# Product rule on first summand
#
# $h'(x) = 8x*sin(x)+4x^2*cos(x)+h'(\frac{e^x}{e^x+1})+h'(x^3)$
#
# Quotient rule on second summand
#
# $h'(x) = 8x*sin(x)+4x^2*cos(x)+\frac{e^x*(e^x+1)-e^{2x}}{(e^x+1)^2}+h'(x^3)$
#
# Fraction can be rewritten as
#
# $h'(x) = 8x*sin(x)+4x^2*cos(x)+\frac{e^x}{(e^x+1)^2}+h'(x^3)$
#
# Power rule on third summand
#
# $h'(x) = 8x*sin(x)+4x^2*cos(x)+\frac{e^x}{(e^x+1)^2}+ 3x^2$
#
# 2.
#
# ![plot of h(x)](desmos_hx.png "h(x)")
#
# 3. $p_1 = -2.8$ global minimum
#
# $p_2 = 0$ saddle point
#
# $p_3 = 2.8$ global maximum
#
# $p_4 = 4.5$ local minimum
#
# 4. If the learning rate is to small, the algorithm will get stuck in local minima, since it will move towards them but can't move out. If it takes only a small step out of the local minimum, it will move back into it with the next step since the (negative) gradient points it in that direction

# %% [markdown]
# ### 1.3 <font color="green">Done</font>
#
# **Sigmoid Function:**
# Derivative: $ \sigma'(x)=\frac{e^x}{(e^x+1)^2}$ (in blue)
#
# ![plot of sigma(x)](desmos_sigmoid.png "sigma(x)")
#
# **Tanh Function:**
# Derivative: $ \tanh(x)'(x)=\frac{4e^{2x}}{(e^{2x}+1)^2}$ (in blue)
#
# ![plot of tanh(x)](desmos_tanh.png "tanh(x)")
#
#
#
# **Relu Function:**
# Derivative: $\text{ReLU}(x) =  \bigg\{ \begin{array}{ll} 0, & x < 0 \\ 1, & x > 0 \\ \end{array}$ (in blue)
#
# ![plot of relu(x)](desmos_relu.png "relu(x)")
#
#
# **Discussion**
# 1. The shapes of sigmoid and tanh are similar, with the sigmoid squeezing values between 0 and 1, and the tanh between -1 and 1, while the ReLU function looks very different, having a linear increase for values > 0 and setting all values < 0 to 0.
#
# 2. Both sigmoid and tanh give a smooth gradient and make clear predictions, whith the tanh being additionally zero-centric, but both suffer from the vanishing gradient problem. The ReLU in contrast doesn't suffer from this problem and is additionally computationally more effective, but it has the "Dying ReLU" problem which means, that for inputs close to zero or that are negative, the gradient will be zero and the network won't learn.

# %% [markdown]
# ## 2.3 Neural Networks Hello World (4 points)
#
# Construct a neural network for the California Housing Prices dataset.
# It is composed of two linear layers with hidden dimensionality of $32$ and ReLU after the first layer: $L_{8\rightarrow 32} \circ \text{ReLU} \circ L_{32 \rightarrow 1}$ where $L_{x\rightarrow y}$ is a linear layer with $y$ hidden nodes (`nn.Linear(x, y)`).
#
# Split your data into dev and training sets (1000 training, 100 dev, discard rest) and optimize these networks with Adam with learning rate $10^{-3}$.
# Report MSE on both training and dev sets. You can use PyTorch built-in functions to solve this exercise.
#
# Notes:
# - Please read [this introduction to the optimization loop in PyTorch](https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html). It should give you a good overview to what PyTorch needs from you to train a neural network.
# - Run your training multiple times with different seeds because the results have quite high variance.
# - There are many optimizers available and Adam is an optimizer that's more complex than SGD (stochastic gradient descent). It has not yet been covered in the lecture but its usage in code is equivalent to that of SGD and performs much better.

# %%
# DONE
# from your solution module import ...
# your outputs should include Training MSE and Dev MSE.
# useful imports

# %load_ext autoreload
# %autoreload 2

import torch
import solution
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader
from sklearn.datasets import fetch_california_housing

# Data preparation

housing = fetch_california_housing()
print(housing.data.shape)
print(housing.target.shape)


# Slicing data
## Train Set

### Standardizing the Data
my_scaler = solution.StandardScaler()
scaled_data= my_scaler.fit_transform(X=housing.data, y=housing.target)

print(type(scaled_data))

### Slice
data_train = torch.from_numpy(np.float32(scaled_data[:1000]))
target_train = torch.from_numpy(np.float32(housing.target[:1000])).reshape([1000,1]) 

### Checking for shapes
print(data_train.shape)
print(target_train.shape)

### train_set is a touple
train_set = (data_train, target_train)

## Dev Set
### Slice
data_dev = torch.from_numpy(np.float32(scaled_data[1000:1100]))
target_dev = torch.from_numpy(np.float32(housing.target[1000:1100])).reshape([100,1])


### checking for shapes
print(data_dev.shape)
print(target_dev.shape)
dev_set = (data_dev,target_dev)

# Loading the data into a Dataloader
custom_train = solution.CustomDataset(train_set)
train_dataloader = DataLoader(custom_train, batch_size=10)

custom_train = solution.CustomDataset(dev_set)
dev_dataloader = DataLoader(custom_train, batch_size=10)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (20640, 8)
# (20640,)
# <class 'numpy.ndarray'>
# torch.Size([1000, 8])
# torch.Size([1000, 1])
# torch.Size([100, 8])
# torch.Size([100, 1])

# %%
model = solution.NeuralNetwork()

loss_fn = nn.MSELoss()
learning_rate = 10**-3

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    solution.train_loop(train_dataloader, model, loss_fn, optimizer)
    solution.test_loop(dev_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 2.2598160527646542
# ------- Test Loop --------
# Avg MSE loss : 0.340870
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.5338893030956388
# ------- Test Loop --------
# Avg MSE loss : 0.888611
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.38454431341961026
# ------- Test Loop --------
# Avg MSE loss : 0.909876
#
# Epoch 4
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.3355079072900116
# ------- Test Loop --------
# Avg MSE loss : 0.874909
#
# Epoch 5
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.32112927839159966
# ------- Test Loop --------
# Avg MSE loss : 0.858340
#
# Epoch 6
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.31462277041748166
# ------- Test Loop --------
# Avg MSE loss : 0.859045
#
# Epoch 7
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.30972934123128654
# ------- Test Loop --------
# Avg MSE loss : 0.865954
#
# Epoch 8
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.3056881629675627
# ------- Test Loop --------
# Avg MSE loss : 0.875300
#
# Epoch 9
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.3019903196208179
# ------- Test Loop --------
# Avg MSE loss : 0.886332
#
# Epoch 10
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.2985842221044004
# ------- Test Loop --------
# Avg MSE loss : 0.898260
#
# Done!

# %% [markdown]
# # Bonus Learning Rate Effect on Performance (1 point)
#
# Run your neural network with different learning rates (scale logarithmically from $10^{-10}$ to $10^{0}$) and observe the effects on performance. Importantly keep the number of optimization steps (epochs) constant. Because the process is very random run the model multiple times (e.g. 3 times) and plot the results. Try to form hypothesis about the results which you got.
#
# Don't worry, the model training can be done on a CPU and is not computationally intensive.

# %%
learning_rates = [10**-i for i in range(0,10)]

# %%
train_loss_list = []
test_loss_list = []

for learning_rate in learning_rates:
    

    model = solution.NeuralNetwork()

    loss_fn = nn.MSELoss()
    learning_rate = learning_rate

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    epochs = 3
    epoch_train_loss = []
    epoch_test_loss =[] 
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")


        train_loss = solution.train_loop(train_dataloader, model, loss_fn, optimizer)
        test_loss = solution.test_loop(dev_dataloader, model, loss_fn)
        epoch_train_loss.append(train_loss)
        epoch_test_loss.append(test_loss)
    train_loss_list.append(sum(epoch_train_loss)/3)
    test_loss_list.append(sum(epoch_test_loss)/3)
# Out:
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 1847.3474535025657
# ------- Test Loop --------
# Avg MSE loss : 591.691671
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 6.019040300697088
# ------- Test Loop --------
# Avg MSE loss : 12261.764491
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 19.0027823744528
# ------- Test Loop --------
# Avg MSE loss : 1107.075627
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 1.0240914997365325
# ------- Test Loop --------
# Avg MSE loss : 0.818194
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.7054352621175348
# ------- Test Loop --------
# Avg MSE loss : 1.501398
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.8418161510303617
# ------- Test Loop --------
# Avg MSE loss : 1.756457
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.6011448030173778
# ------- Test Loop --------
# Avg MSE loss : 1.615038
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.36037473967298866
# ------- Test Loop --------
# Avg MSE loss : 1.420105
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.3727112173102796
# ------- Test Loop --------
# Avg MSE loss : 1.663217
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 3.712915304005146
# ------- Test Loop --------
# Avg MSE loss : 0.696790
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 1.4131839040853083
# ------- Test Loop --------
# Avg MSE loss : 0.954618
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 0.8096831791847944
# ------- Test Loop --------
# Avg MSE loss : 1.034194
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 4.093734477162361
# ------- Test Loop --------
# Avg MSE loss : 1.310761
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 3.6831514593958854
# ------- Test Loop --------
# Avg MSE loss : 1.112631
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 3.298423514068127
# ------- Test Loop --------
# Avg MSE loss : 0.935421
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 4.570093213319779
# ------- Test Loop --------
# Avg MSE loss : 1.899048
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 4.520740772485733
# ------- Test Loop --------
# Avg MSE loss : 1.869227
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 4.472042544484139
# ------- Test Loop --------
# Avg MSE loss : 1.839923
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 6.649209604859352
# ------- Test Loop --------
# Avg MSE loss : 3.161215
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 6.643351575136185
# ------- Test Loop --------
# Avg MSE loss : 3.157194
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 6.6375512802600865
# ------- Test Loop --------
# Avg MSE loss : 3.153207
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.821935793161392
# ------- Test Loop --------
# Avg MSE loss : 2.201910
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.821319211125374
# ------- Test Loop --------
# Avg MSE loss : 2.201581
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.820698968172073
# ------- Test Loop --------
# Avg MSE loss : 2.201253
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.736803807020188
# ------- Test Loop --------
# Avg MSE loss : 2.060874
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.736757885217667
# ------- Test Loop --------
# Avg MSE loss : 2.060845
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.736713187098503
# ------- Test Loop --------
# Avg MSE loss : 2.060816
#
# Epoch 1
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.080054379701615
# ------- Test Loop --------
# Avg MSE loss : 2.166791
#
# Epoch 2
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.080054099559784
# ------- Test Loop --------
# Avg MSE loss : 2.166791
#
# Epoch 3
# -------------------------------
# ------- Training Loop -------
# Traning Loss: 5.080053827166557
# ------- Test Loop --------
# Avg MSE loss : 2.166790

# %%
import matplotlib
import matplotlib.pyplot as plt

# Plot MSE x Learning Rate
plt.scatter(learning_rates, train_loss_list)
plt.xscale("log")
plt.xlabel("Learning Rate - Log Base 10")
plt.ylabel("MSE - Loss (mean of 3 epochs)")
plt.title('Training - Learning Rate x MSE')
# Out:
# Text(0.5, 1.0, 'Training - Learning Rate x MSE')

# %%
# Plot MSE x Learning Rate - Removing 10⁰ since it overshoots terribly
plt.scatter(learning_rates[1:], train_loss_list[1:])
plt.xscale("log")
plt.xlabel("Learning Rate - Log Base 10")
plt.ylabel("MSE - Loss (mean of 3 epochs)")
plt.title('Training - Learning Rate x MSE - without 1')
# Out:
# Text(0.5, 1.0, 'Training - Learning Rate x MSE - without 1')

# %%
plt.scatter(learning_rates, test_loss_list)
plt.xscale("log")
plt.xlabel("Learning Rate - Log Base 10")
plt.ylabel("MSE - Loss (mean of 3 epochs)")
plt.title('Test - Learning Rate x MSE - without 1')
# Out:
# Text(0.5, 1.0, 'Test - Learning Rate x MSE - without 1')

# %%
# Plot MSE x Learning Rate
plt.scatter(learning_rates[1:], test_loss_list[1:])
plt.xscale("log")
plt.xlabel("Learning Rate - Log Base 10")
plt.ylabel("MSE - Loss (mean of 3 epochs)")
plt.title('Test - Learning Rate x MSE - without 1')
# Out:
# Text(0.5, 1.0, 'Test - Learning Rate x MSE - without 1')

# %% [markdown]
# For learning rate 1 the MSE has completely overshoot, we probably have an exploding gradient.
#
# For this exercise, since it was not specified which MSE we should plot, it was
# decided to plot a mean of the MSE for each training epoch. This would allow to
# control the variance a bit and still give us a visualization of the results.
# The conclusion was written after running the experiment a couple of times.
#
# For the training Data the MSE visibly drops when using LR 10^-3, has its lowest
# value on 10^ and increases a bit for higher MSE values.
# This probably means we found a minima in the modeled function.
#
# For the Development (test) Data, the lowest MSE value is found using LR 10^-3.
# This might be the minima for the modeled function.
#
# For variability issues, check this first before running, the conclusion might vary.
